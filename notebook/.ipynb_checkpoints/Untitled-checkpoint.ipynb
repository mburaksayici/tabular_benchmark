# %%
data = "../tabular_benchmark/data/bank/data.csv"

# %%
import os

os.listdir("../")
# Out:
# ['tabular_benchmark', 'notebook', '.git']

# %%
import pandas as pd 




df = pd.read_csv(data, sep = ';')

object_columns_feat = cat_features = df.select_dtypes(include='object').columns.tolist()
"""

for c in object_columns_feat:
    df[c] = df[c].astype('int64')
"""
#object_columns_feat.remove("y")
# Out:
# "\n\nfor c in object_columns_feat:\n    df[c] = df[c].astype('int64')\n"

# %%
def convert_cat_str_to_int(df,cat_features):
    rule_dict = dict()
    for cat_feat in cat_features:
        uniques_ordered = sorted(df[cat_feat].unique().tolist())
        rule_dict[cat_feat] = rule = dict(zip(uniques_ordered,range(len(uniques_ordered))))
        df[cat_feat] = df[cat_feat].map(rule)
    return df, rule_dict




df, rule_dict = convert_cat_str_to_int(df,cat_features)


object_columns_feat.remove("y")

# %%
params = {"data_name":"bank", "link": "https://archive.ics.uci.edu/ml/datasets/Bank+Marketing#", "problem_type":"classification", "numerical_columns": ["age","balance","day", "duration", "pdays", "previous", "y"], "output":"y"}


import json

with open('../tabular_benchmark/data/bank/params.json', 'w') as fp:
    json.dump(params, fp)

# %%
import numpy as np
import optuna

import lightgbm as lgb
import sklearn.datasets
import sklearn.metrics
from sklearn.model_selection import train_test_split


# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def objective(trial):
    data, target = df.loc[:, df.columns != 'y'],  df.loc[:, df.columns == 'y']

    train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)
    dtrain = lgb.Dataset(train_x, label=train_y,   categorical_feature=object_columns_feat)
    dvalid = lgb.Dataset(valid_x, label=valid_y,   categorical_feature=object_columns_feat)
    
    param = {
        "objective": "binary",
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    # Add a callback for pruning.
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
    gbm = lgb.train(param, dtrain, valid_sets=[dvalid], callbacks=[pruning_callback], categorical_feature=object_columns_feat)

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = sklearn.metrics.accuracy_score(valid_y, pred_labels)
    return accuracy


study = optuna.create_study(
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=10), direction="maximize"
)
study.optimize(objective, n_trials=300)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-01-08 23:46:22,095] A new study created in memory with name: no-name-1e00c606-39da-43e1-b876-eea832beb7df
# [I 2023-01-08 23:46:22,716] Trial 0 finished with value: 0.9033884809342653 and parameters: {'lambda_l1': 4.4770964043273106e-08, 'lambda_l2': 0.004537065305454843, 'num_leaves': 164, 'feature_fraction': 0.6341798759207704, 'bagging_fraction': 0.6418340777303274, 'bagging_freq': 4, 'min_child_samples': 28}. Best is trial 0 with value: 0.9033884809342653.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:23,533] Trial 1 finished with value: 0.9007343183225692 and parameters: {'lambda_l1': 1.7296513571614108e-05, 'lambda_l2': 8.380700986535386e-08, 'num_leaves': 219, 'feature_fraction': 0.9692991987457057, 'bagging_fraction': 0.40715272610920017, 'bagging_freq': 3, 'min_child_samples': 16}. Best is trial 0 with value: 0.9033884809342653.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:24,112] Trial 2 finished with value: 0.9054233389365655 and parameters: {'lambda_l1': 0.020763363524458463, 'lambda_l2': 0.000957520271042368, 'num_leaves': 141, 'feature_fraction': 0.876296133941666, 'bagging_fraction': 0.5317009937064265, 'bagging_freq': 5, 'min_child_samples': 39}. Best is trial 2 with value: 0.9054233389365655.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46

# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:30,552] Trial 21 finished with value: 0.9061311156330177 and parameters: {'lambda_l1': 3.3130904698019685e-08, 'lambda_l2': 0.003087017373170639, 'num_leaves': 126, 'feature_fraction': 0.8438468982889821, 'bagging_fraction': 0.9811049346785108, 'bagging_freq': 5, 'min_child_samples': 65}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:30,648] Trial 22 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:30,762] Trial 23 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:31,734] Trial 24 finished with value: 0.910643192072901 and parameters: {'lambda_l1': 1.585513971010679e-06, 'lambda_l2': 0.02210621032866779, 'num_leaves': 221, 'feature_fraction': 0.8187703141911724, 'bagging_fraction': 0.8543839603439143, 'bagging_freq': 5, 'min_child_samples': 53}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:32,623] Trial 25 finished with value: 0.9102008316376183 and parameters: {'lambda_l1': 1.0235112887210034e-08, 'lambda_l2': 0.05431029528763773, 'num_leaves': 223, 'feature_fraction': 0.9930000755839502, 'bagging_fraction': 0.8274245633665203, 'bagging_freq': 4, 'min_child_samples': 42}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:32,762] Trial 26 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:32,879] Trial 27 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:32,980] Trial 28 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:33,145] Trial 29 pruned. Trial was pruned at iteration 13.
# [I 2023-01-08 23:46:33,258] Trial 30 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:33,350] Trial 31 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:34,372] Trial 32 finished with value: 0.9086083340706007 and parameters: {'lambda_l1': 1.1448903153788143e-08, 'lambda_l2': 0.8567025082051023, 'num_leaves': 233, 'feature_fraction': 0.6768484656888503, 'bagging_fraction': 0.9957463409323175, 'bagging_freq': 3, 'min_child_samples': 56}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:34,495] Trial 33 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:34,632] Trial 34 pruned. Trial was pruned at iteration 13.
# [I 2023-01-08 23:46:34,752] Trial 35 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:34,850] Trial 36 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:34,935] Trial 37 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:35,087] Trial 38 pruned. Trial was pruned at iteration 16.
# [I 2023-01-08 23:46:35,193] Trial 39 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:35,276] Trial 40 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:36,221] Trial 41 finished with value: 0.9050694505883394 and parameters: {'lambda_l1': 1.4750001466259609e-08, 'lambda_l2': 0.6912097975045508, 'num_leaves': 231, 'feature_fraction': 0.6753651377281694, 'bagging_fraction': 0.9959133264958591, 'bagging_freq': 3, 'min_child_samples': 56}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:36,319] Trial 42 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:36,515] Trial 43 pruned. Trial was pruned at iteration 22.
# [I 2023-01-08 23:46:37,289] Trial 44 finished with value: 0.9071043085906396 and parameters: {'lambda_l1': 1.7767287019464654e-07, 'lambda_l2': 0.940286840990149, 'num_leaves': 212, 'feature_fraction': 0.7251539253717314, 'bagging_fraction': 0.8833898945417614, 'bagging_freq': 4, 'min_child_samples': 50}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46:37,382] Trial 45 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:46:37,515] Trial 46 pruned. Trial was pruned at iteration 12.
# [I 2023-01-08 23:46:38,231] Trial 47 finished with value: 0.9073697248518092 and parameters: {'lambda_l1': 8.726348106860619e-08, 'lambda_l2': 0.12583937260881017, 'num_leaves': 198, 'feature_fraction': 0.509253925130303, 'bagging_fraction': 0.9315164254215497, 'bagging_freq': 3, 'min_child_samples': 71}. Best is trial 20 with value: 0.9117048571175794.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:46
pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:47:10,544] Trial 293 pruned. Trial was pruned at iteration 15.
# [I 2023-01-08 23:47:10,933] Trial 294 finished with value: 0.9109086083340706 and parameters: {'lambda_l1': 3.267383241740575e-06, 'lambda_l2': 0.7571514428473408, 'num_leaves': 42, 'feature_fraction': 0.9518427707540021, 'bagging_fraction': 0.8468755890982027, 'bagging_freq': 1, 'min_child_samples': 38}. Best is trial 186 with value: 0.9147129080775015.
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-01-08 23:47:11,023] Trial 295 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:47:11,105] Trial 296 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:47:11,181] Trial 297 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:47:11,269] Trial 298 pruned. Trial was pruned at iteration 10.
# [I 2023-01-08 23:47:11,340] Trial 299 pruned. Trial was pruned at iteration 10.
# Number of finished trials: 300
# Best trial:
#   Value: 0.9147129080775015
#   Params:
#     lambda_l1: 3.253992536924809e-05
#     lambda_l2: 0.00016465738435676684
#     num_leaves: 50
#     feature_fraction: 0.9349569006459885
#     bagging_fraction: 0.861221477381807
#     bagging_freq: 2
#     min_child_samples: 43

# %%
study.best_trial
# Out:
# FrozenTrial(number=74, values=[0.9090506945058834], datetime_start=datetime.datetime(2023, 1, 8, 23, 47, 48, 465858), datetime_complete=datetime.datetime(2023, 1, 8, 23, 47, 48, 641716), params={'booster': 'dart', 'lambda': 1.1610032354870255e-06, 'alpha': 0.06642648138648113, 'subsample': 0.6872012415625147, 'colsample_bytree': 0.9649865823227946, 'max_depth': 7, 'min_child_weight': 10, 'eta': 0.0022355174557013645, 'gamma': 3.94017568583284e-05, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.2618260900859333, 'skip_drop': 1.4662474936815081e-08}, distributions={'booster': CategoricalDistribution(choices=('gbtree', 'gblinear', 'dart')), 'lambda': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'alpha': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.2, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.2, step=None), 'max_depth': IntDistribution(high=9, log=False, low=3, step=2), 'min_child_weight': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'gamma': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'grow_policy': CategoricalDistribution(choices=('depthwise', 'lossguide')), 'sample_type': CategoricalDistribution(choices=('uniform', 'weighted')), 'normalize_type': CategoricalDistribution(choices=('tree', 'forest')), 'rate_drop': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'skip_drop': FloatDistribution(high=1.0, log=True, low=1e-08, step=None)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=74, state=TrialState.COMPLETE, value=None)

# %%
    param = {
        "objective": "binary",
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    # Add a callback for pruning.
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
    gbm = lgb.train(param, dtrain, valid_sets=[dvalid], callbacks=[pruning_callback], categorical_feature=object_columns_feat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 6
#       1 param = {
#       2     "objective": "binary",
#       3     "metric": "auc",
#       4     "verbosity": -1,
#       5     "boosting_type": "gbdt",
# ----> 6     "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
#       7     "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
#       8     "num_leaves": trial.suggest_int("num_leaves", 2, 256),
#       9     "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
#      10     "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
#      11     "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
#      12     "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
#      13 }
#      15 # Add a callback for pruning.
#      16 pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
#
# NameError: name 'trial' is not defined

# %%
data, target = df.loc[:, df.columns != 'y'],  df.loc[:, df.columns == 'y']
target = target.astype("category")


train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)
dtrain = lgb.Dataset(train_x, label=train_y,   categorical_feature="auto")
dvalid = lgb.Dataset(valid_x, label=valid_y,   categorical_feature="auto")


param = {
    "objective": "binary",
    "metric": "auc",
    "verbosity": -1,
    "boosting_type": "gbdt",
    "lambda_l1":   1e-8 ,
    "lambda_l2":   1e-8 ,
    "num_leaves":   256,
    "feature_fraction":  0.4 ,
    "bagging_fraction":   1.0,
    "bagging_freq":   7,
    "min_child_samples":   100
}

# Add a callback for pruning.
gbm = lgb.train(param, dtrain, valid_sets=[dvalid] , categorical_feature="auto" )

preds = gbm.predict(valid_x)
pred_labels = np.rint(preds)
accuracy = sklearn.metrics.accuracy_score(valid_y, pred_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 25
#      10 param = {
#      11     "objective": "binary",
#      12     "metric": "auc",
#    (...)
#      21     "min_child_samples":   100
#      22 }
#      24 # Add a callback for pruning.
# ---> 25 gbm = lgb.train(param, dtrain, valid_sets=[dvalid] , categorical_feature="auto" )
#      27 preds = gbm.predict(valid_x)
#      28 pred_labels = np.rint(preds)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/engine.py:271, in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     269 # construct booster
#     270 try:
# --> 271     booster = Booster(params=params, train_set=train_set)
#     272     if is_valid_contain_train:
#     273         booster.set_train_data_name(train_data_name)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:2605, in Booster.__init__(self, params, train_set, model_file, model_str, silent)
#    2598     self.set_network(
#    2599         machines=machines,
#    2600         local_listen_port=params["local_listen_port"],
#    2601         listen_time_out=params.get("time_out", 120),
#    2602         num_machines=params["num_machines"]
#    2603     )
#    2604 # construct booster object
# -> 2605 train_set.construct()
#    2606 # copy the parameters from train_set
#    2607 params.update(train_set.get_params())
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1815, in Dataset.construct(self)
#    1812             self._set_init_score_by_predictor(self._predictor, self.data, used_indices)
#    1813 else:
#    1814     # create train
# -> 1815     self._lazy_init(self.data, label=self.label,
#    1816                     weight=self.weight, group=self.group,
#    1817                     init_score=self.init_score, predictor=self._predictor,
#    1818                     silent=self.silent, feature_name=self.feature_name,
#    1819                     categorical_feature=self.categorical_feature, params=self.params)
#    1820 if self.free_raw_data:
#    1821     self.data = None
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1478, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1473     categorical_feature = reference.categorical_feature
#    1474 data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1475                                                                                      feature_name,
#    1476                                                                                      categorical_feature,
#    1477                                                                                      self.pandas_categorical)
# -> 1478 label = _label_from_pandas(label)
#    1480 # process for args
#    1481 params = {} if params is None else params
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:613, in _label_from_pandas(label)
#     611         raise ValueError('DataFrame for label cannot have multiple columns')
#     612     if _get_bad_pandas_dtypes(label.dtypes):
# --> 613         raise ValueError('DataFrame.dtypes for label must be int, float or bool')
#     614     label = np.ravel(label.values.astype(np.float32, copy=False))
#     615 return label
#
# ValueError: DataFrame.dtypes for label must be int, float or bool

# %%
lgb.train(param, dtrain, valid_sets=[dvalid] , categorical_feature=object_columns_feat )
# Out:
# /Users/mehmetburaksayici/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['contact', 'default', 'education', 'housing', 'job', 'loan', 'marital', 'month', 'poutcome', 'y']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 lgb.train(param, dtrain, valid_sets=[dvalid] , categorical_feature=object_columns_feat )
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/engine.py:271, in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     269 # construct booster
#     270 try:
# --> 271     booster = Booster(params=params, train_set=train_set)
#     272     if is_valid_contain_train:
#     273         booster.set_train_data_name(train_data_name)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:2605, in Booster.__init__(self, params, train_set, model_file, model_str, silent)
#    2598     self.set_network(
#    2599         machines=machines,
#    2600         local_listen_port=params["local_listen_port"],
#    2601         listen_time_out=params.get("time_out", 120),
#    2602         num_machines=params["num_machines"]
#    2603     )
#    2604 # construct booster object
# -> 2605 train_set.construct()
#    2606 # copy the parameters from train_set
#    2607 params.update(train_set.get_params())
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1815, in Dataset.construct(self)
#    1812             self._set_init_score_by_predictor(self._predictor, self.data, used_indices)
#    1813 else:
#    1814     # create train
# -> 1815     self._lazy_init(self.data, label=self.label,
#    1816                     weight=self.weight, group=self.group,
#    1817                     init_score=self.init_score, predictor=self._predictor,
#    1818                     silent=self.silent, feature_name=self.feature_name,
#    1819                     categorical_feature=self.categorical_feature, params=self.params)
#    1820 if self.free_raw_data:
#    1821     self.data = None
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:1478, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1473     categorical_feature = reference.categorical_feature
#    1474 data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1475                                                                                      feature_name,
#    1476                                                                                      categorical_feature,
#    1477                                                                                      self.pandas_categorical)
# -> 1478 label = _label_from_pandas(label)
#    1480 # process for args
#    1481 params = {} if params is None else params
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/lightgbm/basic.py:613, in _label_from_pandas(label)
#     611         raise ValueError('DataFrame for label cannot have multiple columns')
#     612     if _get_bad_pandas_dtypes(label.dtypes):
# --> 613         raise ValueError('DataFrame.dtypes for label must be int, float or bool')
#     614     label = np.ravel(label.values.astype(np.float32, copy=False))
#     615 return label
#
# ValueError: DataFrame.dtypes for label must be int, float or bool

# %%
# Out:
# {'data_name': 'bank',
#  'link': 'https://archive.ics.uci.edu/ml/datasets/Bank+Marketing#',
#  'problem_type': 'classification',
#  'numerical_columns': ['age',
#   'balance',
#   'day',
#   'duration',
#   'pdays',
#   'previous'],
#  'output': 'y'}

# %%
df, rule_dict = convert_cat_str_to_int(df,cat_features)

# %%
rule_dict
# Out:
# {'job': {'admin.': 0,
#   'blue-collar': 1,
#   'entrepreneur': 2,
#   'housemaid': 3,
#   'management': 4,
#   'retired': 5,
#   'self-employed': 6,
#   'services': 7,
#   'student': 8,
#   'technician': 9,
#   'unemployed': 10,
#   'unknown': 11},
#  'marital': {'divorced': 0, 'married': 1, 'single': 2},
#  'education': {'primary': 0, 'secondary': 1, 'tertiary': 2, 'unknown': 3},
#  'default': {'no': 0, 'yes': 1},
#  'housing': {'no': 0, 'yes': 1},
#  'loan': {'no': 0, 'yes': 1},
#  'contact': {'cellular': 0, 'telephone': 1, 'unknown': 2},
#  'month': {'apr': 0,
#   'aug': 1,
#   'dec': 2,
#   'feb': 3,
#   'jan': 4,
#   'jul': 5,
#   'jun': 6,
#   'mar': 7,
#   'may': 8,
#   'nov': 9,
#   'oct': 10,
#   'sep': 11},
#  'poutcome': {'failure': 0, 'other': 1, 'success': 2, 'unknown': 3},
#  'y': {'no': 0, 'yes': 1}}

# %%
df
# Out:
#        age job marital education default  balance housing loan contact  day  \
# 0       58   4       1         2       0     2143       1    0       2    5
# 1       44   9       2         1       0       29       1    0       2    5
# 2       33   2       1         1       0        2       1    1       2    5
# 3       47   1       1         3       0     1506       1    0       2    5
# 4       33  11       2         3       0        1       0    0       2    5
# ...    ...  ..     ...       ...     ...      ...     ...  ...     ...  ...
# 45206   51   9       1         2       0      825       0    0       0   17
# 45207   71   5       0         0       0     1729       0    0       0   17
# 45208   72   5       1         1       0     5715       0    0       0   17
# 45209   57   1       1         1       0      668       0    0       1   17
# 45210   37   2       1         1       0     2971       0    0       0   17
#
#       month  duration  campaign  pdays  previous poutcome  y
# 0         8       261         1     -1         0        3  0
# 1         8       151         1     -1         0        3  0
# 2         8        76         1     -1         0        3  0
# 3         8        92         1     -1         0        3  0
# 4         8       198         1     -1         0        3  0
# ...     ...       ...       ...    ...       ...      ... ..
# 45206     9       977         3     -1         0        3  1
# 45207     9       456         2     -1         0        3  1
# 45208     9      1127         5    184         3        2  1
# 45209     9       508         4     -1         0        3  0
# 45210     9       361         2    188        11        1  0
#
# [45211 rows x 17 columns]

# %%
import xgboost as xgb


def objective(trial):

    data, target = df.loc[:, df.columns != 'y'],  df.loc[:, df.columns == 'y']

    
    train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)
    dtrain = xgb.DMatrix(train_x, label=train_y, enable_categorical = True)
    dvalid = xgb.DMatrix(valid_x, label=valid_y , enable_categorical = True)

    param = {
        "verbosity": 0,
        "objective": "binary:logistic",
        # use exact for small dataset.
        "tree_method": "exact",
        # defines booster, gblinear for linear functions.
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        # L2 regularization weight.
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        # L1 regularization weight.
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        # sampling ratio for training data.
        "subsample": trial.suggest_float("subsample", 0.2, 1.0),
        # sampling according to each tree.
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
    }

    if param["booster"] in ["gbtree", "dart"]:
        # maximum depth of the tree, signifies complexity of the tree.
        param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
        # minimum child weight, larger the term more conservative the tree.
        param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
        param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
        # defines how selective algorithm is.
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

    bst = xgb.train(param, dtrain)
    preds = bst.predict(dvalid)
    pred_labels = np.rint(preds)
    accuracy = sklearn.metrics.accuracy_score(valid_y, pred_labels)
    return accuracy

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: ", len(study.trials))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-01-08 23:47:38,421] A new study created in memory with name: no-name-3d0c66a9-e565-4b94-ad3d-671825448586
# [I 2023-01-08 23:47:38,570] Trial 0 finished with value: 0.8927718304874812 and parameters: {'booster': 'gbtree', 'lambda': 0.0015363259645493103, 'alpha': 1.2517118592479201e-06, 'subsample': 0.9164619919312549, 'colsample_bytree': 0.6455034000829812, 'max_depth': 7, 'min_child_weight': 8, 'eta': 1.4704458005381896e-05, 'gamma': 6.66808018472826e-08, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0.8927718304874812.
# [I 2023-01-08 23:47:38,662] Trial 1 finished with value: 0.892240997965142 and parameters: {'booster': 'gbtree', 'lambda': 1.209064178019936e-06, 'alpha': 0.011327292870551847, 'subsample': 0.9096288941918724, 'colsample_bytree': 0.6526737529597253, 'max_depth': 5, 'min_child_weight': 7, 'eta': 1.4510996485615787e-05, 'gamma': 5.772720734719733e-05, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0.8927718304874812.
# [I 2023-01-08 23:47:38,736] Trial 2 finished with value: 0.8964876581438556 and parameters: {'booster': 'gbtree', 'lambda': 1.2285252900031195e-05, 'alpha': 6.161947176233326e-08, 'subsample': 0.5294429353438509, 'colsample_bytree': 0.2393453048841261, 'max_depth': 5, 'min_child_weight': 6, 'eta': 0.4820793050416498, 'gamma': 1.416833591278076e-06, 'grow_policy': 'lossguide'}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:38,775] Trial 3 finished with value: 0.8879943377864283 and parameters: {'booster': 'gblinear', 'lambda': 0.00335965147485735, 'alpha': 0.0449237205599608, 'subsample': 0.44345946572128414, 'colsample_bytree': 0.5630187427879108}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:38,815] Trial 4 finished with value: 0.8948066884897815 and parameters: {'booster': 'gblinear', 'lambda': 9.370251859071222e-05, 'alpha': 5.254409528153915e-06, 'subsample': 0.9361959132202202, 'colsample_bytree': 0.8924168447620788}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:38,900] Trial 5 finished with value: 0.8908254445722374 and parameters: {'booster': 'gbtree', 'lambda': 5.819488973536396e-08, 'alpha': 0.20200365218398073, 'subsample': 0.5412548439343375, 'colsample_bytree': 0.5335578189212129, 'max_depth': 5, 'min_child_weight': 7, 'eta': 0.0007027944491260725, 'gamma': 1.9604330350717127e-07, 'grow_policy': 'depthwise'}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:38,970] Trial 6 finished with value: 0.8832168450853756 and parameters: {'booster': 'gbtree', 'lambda': 1.994612922759973e-07, 'alpha': 0.047982967991946145, 'subsample': 0.6105897992388671, 'colsample_bytree': 0.6812446965072328, 'max_depth': 3, 'min_child_weight': 9, 'eta': 1.0618883775517002e-07, 'gamma': 7.594549755943718e-05, 'grow_policy': 'depthwise'}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:39,070] Trial 7 finished with value: 0.8925948863133681 and parameters: {'booster': 'gbtree', 'lambda': 0.0011806841387694438, 'alpha': 1.4352017576321356e-06, 'subsample': 0.4384533684298707, 'colsample_bytree': 0.43960280209798175, 'max_depth': 7, 'min_child_weight': 3, 'eta': 2.0454863071505588e-08, 'gamma': 0.002930769844237963, 'grow_policy': 'depthwise'}. Best is trial 2 with value: 0.8964876581438556.
# [I 2023-01-08 23:47:39,279] Trial 8 finished with value: 0.9016190391931346 and parameters: {'booster': 'dart', 'lambda': 8.197570064853234e-08, 'alpha': 0.12515580598001294, 'subsample': 0.8094948742803536, 'colsample_bytree': 0.8897980213180059, 'max_depth': 9, 'min_child_weight': 2, 'eta': 3.737564370411146e-07, 'gamma': 0.00241596201256306, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop':
. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:49,470] Trial 79 finished with value: 0.9072812527647527 and parameters: {'booster': 'dart', 'lambda': 3.86965063530589e-08, 'alpha': 0.022171595416822253, 'subsample': 0.5802562865303472, 'colsample_bytree': 0.945499388192492, 'max_depth': 7, 'min_child_weight': 10, 'eta': 9.679396671583455e-08, 'gamma': 0.8437198969687483, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.18654353009270583, 'skip_drop': 2.8368923342523914e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:49,663] Trial 80 finished with value: 0.9018844554543042 and parameters: {'booster': 'dart', 'lambda': 4.305477751164118e-08, 'alpha': 0.022408899444235773, 'subsample': 0.8452209839365175, 'colsample_bytree': 0.9434077413626558, 'max_depth': 7, 'min_child_weight': 10, 'eta': 3.2785737868346836e-08, 'gamma': 0.16132581174101285, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.04929102976850054, 'skip_drop': 7.107304876777404e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:49,841] Trial 81 finished with value: 0.9050694505883394 and parameters: {'booster': 'dart', 'lambda': 0.0005627754560368464, 'alpha': 0.2081195020920296, 'subsample': 0.6285722818448881, 'colsample_bytree': 0.9689093544286957, 'max_depth': 7, 'min_child_weight': 10, 'eta': 7.349581800804737e-08, 'gamma': 6.163226893469749e-05, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.1276292246394709, 'skip_drop': 1.800202258873494e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,020] Trial 82 finished with value: 0.897549323188534 and parameters: {'booster': 'dart', 'lambda': 2.132090965728816e-08, 'alpha': 0.3228227732361101, 'subsample': 0.6247787987752055, 'colsample_bytree': 0.9717859873448682, 'max_depth': 7, 'min_child_weight': 10, 'eta': 7.107754686622813e-08, 'gamma': 0.07278503511773593, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.1873985346068503, 'skip_drop': 2.1880237832234148e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,193] Trial 83 finished with value: 0.9041847297177741 and parameters: {'booster': 'dart', 'lambda': 1.0587794116169837e-08, 'alpha': 0.1440380352175111, 'subsample': 0.5785893179772459, 'colsample_bytree': 0.9210582622947703, 'max_depth': 7, 'min_child_weight': 9, 'eta': 2.8588976965444863e-06, 'gamma': 0.9073603272281561, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.5151159177702381, 'skip_drop': 2.1474554025619298e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,378] Trial 84 finished with value: 0.8968415464920817 and parameters: {'booster': 'dart', 'lambda': 0.0005918435385257874, 'alpha': 0.07097247189346505, 'subsample': 0.7219357545028786, 'colsample_bytree': 0.8587492426166369, 'max_depth': 7, 'min_child_weight': 9, 'eta': 2.248253467131345e-07, 'gamma': 1.1456099158763911e-05, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.06062585759096435, 'skip_drop': 7.364668939954626e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,492] Trial 85 finished with value: 0.8787932407325488 and parameters: {'booster': 'gbtree', 'lambda': 1.575555103551235e-08, 'alpha': 0.25824980250146057, 'subsample': 0.6952957763628594, 'colsample_bytree': 0.27998860909784623, 'max_depth': 7, 'min_child_weight': 10, 'eta': 1.0033885352393835e-07, 'gamma': 6.733015192351636e-05, 'grow_policy': 'lossguide'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,679] Trial 86 finished with value: 0.9024152879766434 and parameters: {'booster': 'dart', 'lambda': 6.357310912490854e-08, 'alpha': 0.019498272445745042, 'subsample': 0.6619503482538641, 'colsample_bytree': 0.9138655689175115, 'max_depth': 7, 'min_child_weight': 10, 'eta': 5.690141496398258e-07, 'gamma': 3.2470808542543166e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.20786384827513082, 'skip_drop': 1.9686705024137334e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:50,868] Trial 87 finished with value: 0.889763779527559 and parameters: {'booster': 'dart', 'lambda': 3.724125324318509e-08, 'alpha': 0.010042305979617576, 'subsample': 0.5444755068473728, 'colsample_bytree': 0.9423237740903588, 'max_depth': 7, 'min_child_weight': 10, 'eta': 1.1547991041722936e-08, 'gamma': 0.000243447862009279, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.09386373007807279, 'skip_drop': 1.039585508103179e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,024] Trial 88 finished with value: 0.9065734760683004 and parameters: {'booster': 'gbtree', 'lambda': 1.8643139913949343e-06, 'alpha': 0.9743124107879243, 'subsample': 0.6456769072613885, 'colsample_bytree': 0.9672958470225704, 'max_depth': 7, 'min_child_weight': 9, 'eta': 2.3622994508149826e-07, 'gamma': 8.773972612617296e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,181] Trial 89 finished with value: 0.9009997345837388 and parameters: {'booster': 'gbtree', 'lambda': 1.8997465144556922e-06, 'alpha': 0.00811883505025066, 'subsample': 0.7613750187952072, 'colsample_bytree': 0.9445799262007212, 'max_depth': 7, 'min_child_weight': 9, 'eta': 0.0025266761989582924, 'gamma': 9.657531741534485e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,337] Trial 90 finished with value: 0.904007785543661 and parameters: {'booster': 'gbtree', 'lambda': 3.6300645403666046e-06, 'alpha': 0.7848597217967374, 'subsample': 0.6481137521107452, 'colsample_bytree': 0.998881751448287, 'max_depth': 7, 'min_child_weight': 9, 'eta': 1.5512027071548823e-06, 'gamma': 0.0015599695348923795, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,494] Trial 91 finished with value: 0.902680704237813 and parameters: {'booster': 'gbtree', 'lambda': 9.4666453911919e-07, 'alpha': 0.4081107491299293, 'subsample': 0.6359633082514894, 'colsample_bytree': 0.970769484067268, 'max_depth': 7, 'min_child_weight': 10, 'eta': 2.2592811051184434e-07, 'gamma': 3.901432171939156e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,646] Trial 92 finished with value: 0.9039193134566045 and parameters: {'booster': 'gbtree', 'lambda': 5.127913992699819e-07, 'alpha': 0.033785899588186355, 'subsample': 0.6024154365084556, 'colsample_bytree': 0.9044681892207744, 'max_depth': 7, 'min_child_weight': 10, 'eta': 7.912904819597314e-08, 'gamma': 1.7376223180242148e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:51,815] Trial 93 finished with value: 0.8997611253649473 and parameters: {'booster': 'gbtree', 'lambda': 0.00013285549191381006, 'alpha': 0.1147142162292384, 'subsample': 0.6752357074027955, 'colsample_bytree': 0.9602230909593203, 'max_depth': 7, 'min_child_weight': 10, 'eta': 4.4477225736033075e-08, 'gamma': 6.443015643532966e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,003] Trial 94 finished with value: 0.8990533486684951 and parameters: {'booster': 'dart', 'lambda': 1.2410460593443633e-07, 'alpha': 0.16033427413152732, 'subsample': 0.5081517274640106, 'colsample_bytree': 0.9809509760496923, 'max_depth': 7, 'min_child_weight': 10, 'eta': 1.805042106517879e-07, 'gamma': 0.0005119315164480346, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.5596378154972055, 'skip_drop': 1.5899557790311627e-07}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,052] Trial 95 finished with value: 0.8902061399628417 and parameters: {'booster': 'gblinear', 'lambda': 5.923985218420877e-06, 'alpha': 0.004098759575233345, 'subsample': 0.579549772426088, 'colsample_bytree': 0.9286970268271361}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,181] Trial 96 finished with value: 0.8904715562240113 and parameters: {'booster': 'gbtree', 'lambda': 3.0924411209633647e-07, 'alpha': 0.2147897089060666, 'subsample': 0.6177146048273107, 'colsample_bytree': 0.5330954780570442, 'max_depth': 7, 'min_child_weight': 9, 'eta': 0.005708096082055271, 'gamma': 0.00013638132615563932, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,371] Trial 97 finished with value: 0.8986109882332124 and parameters: {'booster': 'dart', 'lambda': 0.0019055616065528753, 'alpha': 0.8441959776391368, 'subsample': 0.5563176921003787, 'colsample_bytree': 0.8657778733674373, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.23764745752509267, 'gamma': 0.3480689150128665, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.2001450319825099, 'skip_drop': 5.0979013423832586e-08}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,512] Trial 98 finished with value: 0.8836592055206582 and parameters: {'booster': 'dart', 'lambda': 3.964108633148094e-05, 'alpha': 0.05608944836260352, 'subsample': 0.6377604576729934, 'colsample_bytree': 0.3961465281224574, 'max_depth': 7, 'min_child_weight': 10, 'eta': 1.6713291100424006e-05, 'gamma': 7.025779430223084e-06, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.05080666391466167, 'skip_drop': 5.556784782942786e-07}. Best is trial 74 with value: 0.9090506945058834.
# [I 2023-01-08 23:47:52,644] Trial 99 finished with value: 0.9027691763248695 and parameters: {'booster': 'gbtree', 'lambda': 6.653803623169429e-05, 'alpha': 0.0833264535813147, 'subsample': 0.3082136735039726, 'colsample_bytree': 0.9825924149741219, 'max_depth': 7, 'min_child_weight': 10, 'eta': 3.9358134223154266e-07, 'gamma': 3.0371288284473456e-05, 'grow_policy': 'depthwise'}. Best is trial 74 with value: 0.9090506945058834.
# Number of finished trials:  100
# Best trial:
#   Value: 0.9090506945058834
#   Params:
#     booster: dart
#     lambda: 1.1610032354870255e-06
#     alpha: 0.06642648138648113
#     subsample: 0.6872012415625147
#     colsample_bytree: 0.9649865823227946
#     max_depth: 7
#     min_child_weight: 10
#     eta: 0.0022355174557013645
#     gamma: 3.94017568583284e-05
#     grow_policy: lossguide
#     sample_type: weighted
#     normalize_type: forest
#     rate_drop: 0.2618260900859333
#     skip_drop: 1.4662474936815081e-08

# %%
df.loc[:, df.columns == 'y']
# Out:
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 45206  yes
# 45207  yes
# 45208  yes
# 45209   no
# 45210   no
#
# [45211 rows x 1 columns]

# %%
data, target = df.loc[:, df.columns != 'y'],  df.loc[:, df.columns == 'y']
target = target.astype("category")


train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)
dtrain = xgb.DMatrix(train_x, label=train_y, enable_categorical = True)
dvalid = xgb.DMatrix(valid_x, label=valid_y , enable_categorical = True)

param = {
    "verbosity": 0,
    "objective": "binary:logistic",
    # use exact for small dataset.
    "tree_method": "exact",
    # defines booster, gblinear for linear functions.
    "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
    # L2 regularization weight.
    "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
    # L1 regularization weight.
    "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
    # sampling ratio for training data.
    "subsample": trial.suggest_float("subsample", 0.2, 1.0),
    # sampling according to each tree.
    "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
}

if param["booster"] in ["gbtree", "dart"]:
    # maximum depth of the tree, signifies complexity of the tree.
    param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
    # minimum child weight, larger the term more conservative the tree.
    param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
    param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
    # defines how selective algorithm is.
    param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
    param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

if param["booster"] == "dart":
    param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
    param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
    param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
    param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

bst = xgb.train(param, dtrain)
preds = bst.predict(dvalid)
pred_labels = np.rint(preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 6
#       2 target = target.astype("category")
#       5 train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)
# ----> 6 dtrain = xgb.DMatrix(train_x, label=train_y, enable_categorical = True)
#       7 dvalid = xgb.DMatrix(valid_x, label=valid_y , enable_categorical = True)
#       9 param = {
#      10     "verbosity": 0,
#      11     "objective": "binary:logistic",
#    (...)
#      23     "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
#      24 }
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/core.py:754, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     751 assert handle is not None
#     752 self.handle = handle
# --> 754 self.set_info(
#     755     label=label,
#     756     weight=weight,
#     757     base_margin=base_margin,
#     758     group=group,
#     759     qid=qid,
#     760     label_lower_bound=label_lower_bound,
#     761     label_upper_bound=label_upper_bound,
#     762     feature_weights=feature_weights,
#     763 )
#     765 if feature_names is not None:
#     766     self.feature_names = feature_names
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/core.py:819, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     816 from .data import dispatch_meta_backend
#     818 if label is not None:
# --> 819     self.set_label(label)
#     820 if weight is not None:
#     821     self.set_weight(weight)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/core.py:950, in DMatrix.set_label(self, label)
#     942 """Set label of dmatrix
#     943
#     944 Parameters
#    (...)
#     947     The label information to be set into DMatrix
#     948 """
#     949 from .data import dispatch_meta_backend
# --> 950 dispatch_meta_backend(self, label, 'label', 'float')
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/data.py:1117, in dispatch_meta_backend(matrix, data, name, dtype)
#    1115     return
#    1116 if _is_pandas_df(data):
# -> 1117     data, _, _ = _transform_pandas_df(data, False, meta=name, meta_type=dtype)
#    1118     _meta_from_numpy(data, name, dtype, handle)
#    1119     return
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/data.py:378, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     366 from pandas.api.types import (
#     367     is_sparse,
#     368     is_categorical_dtype,
#     369 )
#     371 if not all(
#     372     dtype.name in _pandas_dtype_mapper
#     373     or is_sparse(dtype)
#    (...)
#     376     for dtype in data.dtypes
#     377 ):
# --> 378     _invalid_dataframe_dtype(data)
#     380 feature_names, feature_types = _pandas_feature_info(
#     381     data, meta, feature_names, feature_types, enable_categorical
#     382 )
#     384 transformed = _pandas_cat_null(data)
#
# File ~/Desktop/venv/venv/lib/python3.8/site-packages/xgboost/data.py:270, in _invalid_dataframe_dtype(data)
#     268 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     269 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 270 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:y: category

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]
